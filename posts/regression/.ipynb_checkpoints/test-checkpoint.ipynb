# %% [raw]
# ---
# title: Simpson's Paradox with Regression
# description: python test
# author: "JS HUHH"
# date: "06/26/2022"
# #image: "https://miro.medium.com/max/259/1*Psa5h9I8zm0lPSsqAgaZHw.png"
# categories: [regression]
# draft: true
# format:
#   html:
#     code-fold: true
# jupyter: python3
# #margin-header: subscribe.html
# ---

# %% [markdown]
# ## 회귀 분석으로 보는 심슨의 역설
#
# 심슨의 역설을 보통은 회귀 분석으로 설명하지 않는다. 그런데 회귀 분석으로 보면 보다 명확하다.
#
# :::{ .column-margin }
# 데이터는 [여기](https://towardsdatascience.com/the-curious-case-of-simpsons-paradox-6f178548d7e8)서 갖고 있다.
# :::

# %%
# Basic packages
import pandas as pd 
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# Stats models 
import statsmodels.formula.api as sm
import statsmodels.stats.sandwich_covariance as sw
import statsmodels as statsmodels
from linearmodels import PanelOLS, FamaMacBeth
# %matplotlib inline

csv_addr = "data/penguins_size.csv"
#plt.rcParams['figure.figsize'] = 12, 10
plt.style.use("fivethirtyeight")# for pretty graphs
df  = pd.read_csv('data/penguins_size.csv')
df.head()
df.info()
df = df.dropna()
df.info()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [92], in <cell line: 18>()
#      16 #plt.rcParams['figure.figsize'] = 12, 10
#      17 plt.style.use("fivethirtyeight")# for pretty graphs
# ---> 18 df  = pd.read_csv('data/penguins_size.csv')
#      19 df.head()
#      20 df.info()
#
# File ~/miniconda3/envs/py10+pandas/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# create df
x = np.linspace(0, 2 * np.pi, 400)
df = pd.DataFrame({'x': x, 'y': np.sin(x ** 2)})
df.index.names = ['obs']
df.columns.names = ['vars']

idx = np.array(df.index.tolist(), dtype='float')  # make an array of x-values

# call regplot on each axes
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=idx, y=df['x'], ax=ax1)
sns.regplot(x=idx, y=df['y'], ax=ax2)
# Out:
# <AxesSubplot:ylabel='y'>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False)
plt.figure(figsize=(10, 8))
sns.regplot(x = 'culmen_length_mm',y = 'culmen_depth_mm', data = df, ax=ax1)
r = stats.pearsonr(df['culmen_length_mm'], df['culmen_depth_mm'])[0]
ax1.text(.03, 1, 'r={:.3f}'.format(r), transform=ax1.transAxes)
colors = ['darkorange', 'royalblue', '#555555']
markers = ['.', '+', 'x']
#graph = sns.lmplot(x='x_value', y='y_value', hue='water_value', data=df, fit_reg=False)
#Use regplot to plot the regression line for the whole points
#sns.regplot(x='x_value', y='y_value', data=df, scatter=False, ax=graph.axes[0, 0]))
for i, value in enumerate(df['species'].unique()):
    ax2 = sns.regplot(x="culmen_length_mm", y="culmen_depth_mm", ax=ax2,
                     color=colors[i],
                     marker=markers[i], 
                     data=df[df['species'] == value],
                     label=value)

# %%
ols1 = sm.ols(formula="culmen_depth_mm ~ culmen_length_mm", data=df).fit(use_t=True)
ols1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        culmen_depth_mm   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     18.31
# Date:                Sat, 04 Jun 2022   Prob (F-statistic):           2.45e-05
# Time:                        20:53:00   Log-Likelihood:                -690.57
# No. Observations:                 334   AIC:                             1385.
# Df Residuals:                     332   BIC:                             1393.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
ols2 = sm.ols(formula="culmen_depth_mm ~ species + culmen_length_mm", data=df).fit(use_t=True)
ols2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        culmen_depth_mm   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     360.8
# Date:                Sat, 04 Jun 2022   Prob (F-statistic):          8.37e-104
# Time:                        20:52:56   Log-Likelihood:                -456.74
# No. Observations:                 334   AIC:                             921.5
# Df Residuals:                     330   BIC:                             936.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
from stargazer.stargazer import Stargazer

stargazer = Stargazer([ols1, ols2])

# %%
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable:culmen_depth_mm</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>20.786<sup>***</sup></td><td>10.619<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.854)</td><td>(0.691)</td></tr><tr><td style="text-align:left">culmen_length_mm</td><td>-0.082<sup>***</sup></td><td>0.199<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.019)</td><td>(0.018)</td></tr><tr><td style="text-align:left">species[T.Chinstrap]</td><td></td><td>-1.919<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.226)</td></tr><tr><td style="text-align:left">species[T.Gentoo]</td><td></td><td>-5.080<sup>*
# ...
